# %%
import numpy as np
import pandas as pd
import requests
import datetime
import MetaTrader5 as mt5
import pickle
import time
mt5.initialize()
# Out:
# True

# %%
#INPUTS
SYMBOL       = 'USDCHF'
TIMEFRAME    = mt5.TIMEFRAME_H4
VOLUME       = 5.0
DEVIATION    = 10
point        = mt5.symbol_info(SYMBOL).point

# %%
def market_order(symbol, volume, order_type, **kwargs):
    tick = mt5.symbol_info_tick(symbol)
    order_dict = {'buy': 0, 'sell': 1}
    price_dict = {'buy': tick.ask, 'sell': tick.bid}
    request = {
        "action": mt5.TRADE_ACTION_DEAL,
        "symbol": symbol,
        "volume": volume,
        "type": order_dict[order_type],
        "price": price_dict[order_type],
        "deviation": DEVIATION,
        "magic": 100,
        "comment": "python market order",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_IOC,
    }

    order_result = mt5.order_send(request)
    print(order_result)

    return order_result

#---------------------------------------------------------------------------------------------------------------------------------
#In[2] FUNCTION - CLOSING AN OPEN ORDER

def close_order(ticket,symbol):
    positions = mt5.positions_get()

    for pos in positions :
        tick = mt5.symbol_info_tick(pos.symbol)
        type_dict = {0: 1, 1: 0}  # 0 represents buy, 1 represents sell - inverting order_type to close the position
        price_dict = {0: tick.ask, 1: tick.bid}
        
        if pos.ticket==ticket and pos.symbol == symbol:
            request = {
                    "action":mt5.TRADE_ACTION_DEAL,
                    "position":pos.ticket,
                    "symbol":pos.symbol,
                    "volume":pos.volume,
                    "type":type_dict[pos.type],
                    "price":price_dict[pos.type],
                    "deviation": DEVIATION,
                    "magic":100,
                    "comment":"python close order",
                    "type_time":mt5.ORDER_TIME_GTC,
                    "type_filling":mt5.ORDER_FILLING_IOC,
            }           
            order_result = mt5.order_send(request)
            print(order_result)
            
            return order_result
        
    return "Ticket doesn't Exist"  

def get_exposure(symbol):
    positions = mt5.positions_get(symbol=symbol)
    if positions:
        pos_df = pd.DataFrame(positions,columns=positions[0]._asdict().keys())
        exposure = pos_df['volume'].sum()
        
        return exposure

# %%
while True : 
    #calculating account exposure
    exposure = get_exposure(SYMBOL)

    rates = mt5.copy_rates_from_pos(SYMBOL,TIMEFRAME,1,21)
    df = pd.DataFrame(rates)
    df['SMA10'] = df['close'].rolling(10).mean()
    df['SMA20'] = df['close'].rolling(20).mean()
    def signal(raw):
        
        if raw['SMA10'] > raw['SMA20']:
            return 1
        elif raw['SMA10']  < raw['SMA20']:
            return 0
        else :
            return np.NaN

    df['Signal'] = df.apply(signal,axis=1)
    df['timestamp_unix'] = df['time'].astype(np.int64) / 10**9 
    df.dropna(inplace=True)
    model = pickle.load(open(r"D:\SY - Class\Forex-market-analysis\rfc2.pkl","rb"))
    y = model.predict(df[['open','high','low','close','SMA10','Signal','SMA20']])
    pred_test = y
    direction = None
    if pred_test[0] == 1 :
        if df['Signal'] == 1:
            direction = 'buy'
        elif df['Signal'] == 0:
            direction = 'sell'
    else :
        direction = 'Non - Profitable Signal'
        
    # trading logic
    if direction == 'buy':
        # if we have a BUY signal, close all short positions
        for pos in mt5.positions_get():
            if pos.type == 1 and pos.symbol == SYMBOL:  # pos.type == 1 represent a sell order
                close_order(pos.ticket,SYMBOL)
        flag = True
        for pos in mt5.positions_get():
            if pos.symbol != SYMBOL:
                flag = False
                break
        # if there are no open positions, open a new long position
        if (flag == False and exposure == None) or (mt5.positions_total() == 0):
            market_order(SYMBOL, VOLUME, direction)

    elif direction == 'sell':
        # if we have a SELL signal, close all short positions
        for pos in mt5.positions_get():
            if pos.type == 0 and pos.symbol == SYMBOL:  # pos.type == 0 represent a buy order
                close_order(pos.ticket,SYMBOL)

        # if there are no open positions, open a new short position
        flag = True
        for pos in mt5.positions_get():
            if pos.symbol != SYMBOL:
                flag = False
                break
        if (flag == False and exposure == None) or (mt5.positions_total() == 0):
            market_order(SYMBOL, VOLUME, direction)
            print('Sell')
    
    print("Time                  :",datetime.datetime.now())
    print("Exposure              :",exposure)
    print("SIGNAL                :",direction)
    print("SYMBOL                :",SYMBOL)
    print("TIMEFRAME             :",str(TIMEFRAME))
    print("----------------------\n")
    
    if len(mt5.positions_get()) >= 1:
        time.sleep(7200)
    elif direction == 'Non - Profitable Signal':
        time.sleep(7200)
    elif direction == None:
        time.sleep(1)
        continue
    else:
        time.sleep(1)
        continue
# Out:
# Time                  : 2023-11-07 12:07:35.247131
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:37.441508
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:39.053060
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:40.311040
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:41.402394
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:42.507044
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:43.595093
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:44.694844
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:45.833571
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:47.065054
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:48.229348
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:49.309910
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:50.388994
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:51.469178
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:52.549063
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:53.623956
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:54.724445
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:55.818717
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:56.962641
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:58.088279
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:07:59.201413
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:00.317473
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:01.396957
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:02.483054
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:03.566465
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:04.718530
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:05.830259
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:06.944080
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:08.024106
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:09.119254
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:10.296577
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:11.499330
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:12.584972
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:13.663090
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:14.754216
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:15.887320
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
#
# Time                  : 2023-11-07 12:08:16.997212
# Exposure              : None
# SIGNAL                : Non - Profitable Signal
# SYMBOL                : USDCHF
# TIMEFRAME             : 16388
# ----------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\SY - Class\Forex-market-analysis\Dep_1_Reg\model1.ipynb Cell 4 line 7
#      <a href='vscode-notebook-cell:/d%3A/SY%20-%20Class/Forex-market-analysis/Dep_1_Reg/model1.ipynb#W3sZmlsZQ%3D%3D?line=74'>75</a>     continue
#      <a href='vscode-notebook-cell:/d%3A/SY%20-%20Class/Forex-market-analysis/Dep_1_Reg/model1.ipynb#W3sZmlsZQ%3D%3D?line=75'>76</a> else:
# ---> <a href='vscode-notebook-cell:/d%3A/SY%20-%20Class/Forex-market-analysis/Dep_1_Reg/model1.ipynb#W3sZmlsZQ%3D%3D?line=76'>77</a>     time.sleep(1)
#      <a href='vscode-notebook-cell:/d%3A/SY%20-%20Class/Forex-market-analysis/Dep_1_Reg/model1.ipynb#W3sZmlsZQ%3D%3D?line=77'>78</a>     continue
#
# KeyboardInterrupt:
