# %%
import os

directory_path = '/Users/drishttinarwal/Documents/Forex-market-analysis-main/datasets/eurusd'
contents = os.listdir(directory_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/drishttinarwal/Documents/Forex-market-analysis-main/datasets/eurusd/eurusd_mn1.csv")

# %%
df
# Out:
#      Unnamed: 0        time     open     high      low    close  tick_volume  \
# 0             0  2012-01-01  1.29443  1.32330  1.26241  1.30879      1771091
# 1             1  2012-02-01  1.30881  1.34856  1.29745  1.33232      1748617
# 2             2  2012-03-01  1.33227  1.33848  1.30032  1.33408      1595899
# 3             3  2012-04-01  1.33562  1.33801  1.29945  1.32417      1484306
# 4             4  2012-05-01  1.32416  1.32828  1.23362  1.23597      1791217
# ..          ...         ...      ...      ...      ...      ...          ...
# 115         115  2021-08-01  1.18676  1.18997  1.16640  1.18086       787889
# 116         116  2021-09-01  1.18088  1.19090  1.15627  1.15769       963100
# 117         117  2021-10-01  1.15822  1.16922  1.15245  1.15637       937759
# 118         118  2021-11-01  1.15558  1.16165  1.11864  1.13386      1123036
# 119         119  2021-12-01  1.13348  1.13864  1.12219  1.13847       971109
#
#      spread  real_volume
# 0         4            0
# 1         4            0
# 2         5            0
# 3         5            0
# 4         5            0
# ..      ...          ...
# 115       0            0
# 116       0            0
# 117       0            0
# 118       0            0
# 119       0            0
#
# [120 rows x 9 columns]

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 0    2012-01-01  1.29443  1.32330  1.26241  1.30879      1771091       4
# 1    2012-02-01  1.30881  1.34856  1.29745  1.33232      1748617       4
# 2    2012-03-01  1.33227  1.33848  1.30032  1.33408      1595899       5
# 3    2012-04-01  1.33562  1.33801  1.29945  1.32417      1484306       5
# 4    2012-05-01  1.32416  1.32828  1.23362  1.23597      1791217       5
# ..          ...      ...      ...      ...      ...          ...     ...
# 115  2021-08-01  1.18676  1.18997  1.16640  1.18086       787889       0
# 116  2021-09-01  1.18088  1.19090  1.15627  1.15769       963100       0
# 117  2021-10-01  1.15822  1.16922  1.15245  1.15637       937759       0
# 118  2021-11-01  1.15558  1.16165  1.11864  1.13386      1123036       0
# 119  2021-12-01  1.13348  1.13864  1.12219  1.13847       971109       0
#
#      real_volume
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 115            0
# 116            0
# 117            0
# 118            0
# 119            0
#
# [120 rows x 8 columns]

# %%
df['SMA10'] = df['close'].rolling(10).mean()
df['SMA20'] = df['close'].rolling(20).mean()

# %%
df.isna().sum()
# Out:
# time            0
# open            0
# high            0
# low             0
# close           0
# tick_volume     0
# spread          0
# real_volume     0
# SMA10           9
# SMA20          19
# dtype: int64

# %%
df['SMA10'].head(20)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     1.287137
# 10    1.286106
# 11    1.284838
# 12    1.287299
# 13    1.285547
# 14    1.290098
# 15    1.295107
# 16    1.302074
# 17    1.306369
# 18    1.310737
# 19    1.313350
# Name: SMA10, dtype: float64

# %%
df['SMA20'].head(30)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19    1.300244
# 20    1.302412
# 21    1.303735
# 22    1.304982
# 23    1.307711
# 24    1.313338
# 25    1.319018
# 26    1.326391
# 27    1.332826
# 28    1.336698
# 29    1.340371
# Name: SMA20, dtype: float64

# %%
df.dropna()
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 19   2013-08-01  1.33022  1.34518  1.31750  1.32195       941655       1
# 20   2013-09-01  1.32122  1.35685  1.31047  1.35215       713383       1
# 21   2013-10-01  1.35215  1.38320  1.34734  1.35880       791255       1
# 22   2013-11-01  1.35878  1.36214  1.32959  1.35901       733298       1
# 23   2013-12-01  1.35878  1.38930  1.35241  1.37876       732363       1
# ..          ...      ...      ...      ...      ...          ...     ...
# 115  2021-08-01  1.18676  1.18997  1.16640  1.18086       787889       0
# 116  2021-09-01  1.18088  1.19090  1.15627  1.15769       963100       0
# 117  2021-10-01  1.15822  1.16922  1.15245  1.15637       937759       0
# 118  2021-11-01  1.15558  1.16165  1.11864  1.13386      1123036       0
# 119  2021-12-01  1.13348  1.13864  1.12219  1.13847       971109       0
#
#      real_volume     SMA10     SMA20
# 19             0  1.313350  1.300244
# 20             0  1.318717  1.302412
# 21             0  1.322633  1.303735
# 22             0  1.322665  1.304982
# 23             0  1.329876  1.307711
# ..           ...       ...       ...
# 115            0  1.198670  1.166940
# 116            0  1.195182  1.169352
# 117            0  1.188651  1.172026
# 118            0  1.180670  1.173541
# 119            0  1.173781  1.175706
#
# [101 rows x 10 columns]

# %%
df[['close','SMA10','SMA20']].head(500).plot(figsize=(40,20))
plt.show()
